# %% [markdown]
# Lab 4: Pandas
#
# Nidhi Mehta
#
# 0827CI191039

# %%
import sys
import pandas as pd 
import matplotlib 

from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# Pandas version 1.3.5
# Matplotlib version 3.2.2

# %%
names = ['A', 'B', 'C', 'D', 'E']
births = [96, 50, 80, 78, 97]
DataSet = list(zip(names, births))
print(DataSet)
# Out:
# [('A', 96), ('B', 50), ('C', 80), ('D', 78), ('E', 97)]

# %%
ds = pd.DataFrame(data = DataSet, columns=['Names', 'Births'])
print(ds)
# Out:
#   Names  Births
# 0     A      96
# 1     B      50
# 2     C      80
# 3     D      78
# 4     E      97

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
ds = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/statewisetestingsamples.csv")
Ds1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Salary_Data.csv")
ds.set_index("TotalSamples")
print(ds)
print(Ds1)
# Out:
#             Date                        State  TotalSamples  Negative  \
# 0     17/04/2020  Andaman and Nicobar Islands          1403    1210.0
# 1     24/04/2020  Andaman and Nicobar Islands          2679       NaN
# 2     27/04/2020  Andaman and Nicobar Islands          2848       NaN
# 3     01/05/2020  Andaman and Nicobar Islands          3754       NaN
# 4     16/05/2020  Andaman and Nicobar Islands          6677       NaN
# ...          ...                          ...           ...       ...
# 1770  01/06/2020                  West Bengal        213231       NaN
# 1771  02/06/2020                  West Bengal        222726       NaN
# 1772  03/06/2020                  West Bengal        232225       NaN
# 1773  04/06/2020                  West Bengal        241831       NaN
# 1774  05/06/2020                  West Bengal        251517       NaN
#
#       Positive
# 0         12.0
# 1         27.0
# 2         33.0
# 3         33.0
# 4         33.0
# ...        ...
# ...

# %%
Ds2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")
print(Ds2)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
Ds2.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
Ds1.sort_values(['Salary'], ascending = False)
# Out:
#     YearsExperience  Salary
# 28             10.3  122391
# 29             10.5  121872
# 26              9.5  116969
# 23              8.2  113812
# 27              9.6  112635
# 24              8.7  109431
# 25              9.0  105582
# 22              7.9  101302
# 21              7.1   98273
# 19              6.0   93940
# 20              6.8   91738
# 17              5.3   83088
# 18              5.9   81363
# 15              4.9   67938
# 16              5.1   66029
# 8               3.2   64445
# 10              3.9   63218
# 14              4.5   61111
# 6               3.0   60150
# 9               3.7   57189
# 13              4.1   57081
# 12              4.0   56957
# 5               2.9   56642
# 11              4.0   55794
# 7               3.2   54445
# 1               1.3   46205
# 3               2.0   43525
# 4               2.2   39891
# 0               1.1   39343
# 2               1.5   37731

# %%
Sorted = ds.sort_values(['Negative'], ascending=False)
Sorted.head(50)
# Out:
#             Date           State  TotalSamples  Negative  Positive
# 1546  06/06/2020      Tamil Nadu        576695  550643.0   30152.0
# 1545  05/06/2020      Tamil Nadu        560673  535254.0   28694.0
# 1544  04/06/2020      Tamil Nadu        544981  517137.0   27256.0
# 1543  03/06/2020      Tamil Nadu        528534  502173.0   25872.0
# 1542  02/06/2020      Tamil Nadu        514433  489258.0   24586.0
# 1541  01/06/2020      Tamil Nadu        503339  479208.0   23495.0
# 1540  31/05/2020      Tamil Nadu        491962  468940.0   22333.0
# 1452  05/06/2020       Rajasthan        480910  465349.0   10084.0
# 1539  30/05/2020      Tamil Nadu        479155  457405.0   21184.0
# 1451  04/06/2020       Rajasthan        467129  451826.0    9862.0
# 1049  06/06/2020     Maharashtra        538009  451764.0   80229.0
# 1538  29/05/2020      Tamil Nadu        466550  445668.0   20246.0
# 1450  03/06/2020       Rajasthan        454788  440850.0    9652.0
# ...

# %%
ds.loc[56]
# Out:
# Date                30/05/2020
# State           Andhra Pradesh
# TotalSamples            363378
# Negative              359917.0
# Positive                2944.0
# Name: 56, dtype: object

# %%
ds.rank()
# Out:
#         Date   State  TotalSamples  Negative  Positive
# 0      927.5     3.5         239.0     150.0     301.0
# 1     1346.0     3.5         340.0       NaN     382.5
# 2     1520.5     3.5         350.0       NaN     419.5
# 3       18.5     3.5         417.0       NaN     419.5
# 4      897.5     3.5         579.5       NaN     419.5
# ...      ...     ...           ...       ...       ...
# 1770    48.5  1744.5        1631.0       NaN    1576.0
# 1771   116.0  1744.5        1643.0       NaN    1584.0
# 1772   181.5  1744.5        1653.0       NaN    1594.0
# 1773   247.0  1744.5        1664.0       NaN    1603.0
# 1774   318.5  1744.5        1671.0       NaN    1614.0
#
# [1775 rows x 5 columns]

# %%
ds.head()
# Out:
#          Date                        State  TotalSamples  Negative  Positive
# 0  17/04/2020  Andaman and Nicobar Islands          1403    1210.0      12.0
# 1  24/04/2020  Andaman and Nicobar Islands          2679       NaN      27.0
# 2  27/04/2020  Andaman and Nicobar Islands          2848       NaN      33.0
# 3  01/05/2020  Andaman and Nicobar Islands          3754       NaN      33.0
# 4  16/05/2020  Andaman and Nicobar Islands          6677       NaN      33.0

# %%
grpby = ds.groupby("State")
print(grpby)
